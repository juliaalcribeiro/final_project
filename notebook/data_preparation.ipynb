# %%
import yaml
 
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Yaml configuration file not found!")

# %%
# ------------------------------------------------------------------
# 1 - Load dataset
# ------------------------------------------------------------------

import pandas as pd

df = pd.read_csv(config['input_data']['file'])
df
# Out:
#                 wine_type wine_category          food_item food_category  \
# 0            Syrah/Shiraz           Red     smoked sausage     Smoky BBQ
# 1                Grenache           Red  charcuterie board   Salty Snack
# 2                 Madeira     Fortified         lemon tart       Dessert
# 3      Cabernet Sauvignon           Red         roast lamb      Red Meat
# 4                Viognier         White    duck à l’orange       Poultry
# ...                   ...           ...                ...           ...
# 34928              Merlot           Red     mac and cheese        Cheese
# 34929           Sauternes       Dessert     grilled ribeye      Red Meat
# 34930           Sauternes       Dessert             fondue        Cheese
# 34931           Zinfandel           Red          beef stew      Red Meat
# 34932            Albariño         White         roast lamb      Red Meat
#
#               cuisine  pairing_quality quality_label  \
# 0             Spanish                2          Poor
# 1              French                3       Neutral
# 2              French                4          Good
# 3             Mexican                5     Excellent
# 4          Vietnamese                2          Poor
# ...               ...              ...           ...
# 34928           Greek                5     Excellent
# 34929         Spanish                5     Excellent
# 34930         Mexican                1      Terrible
# 34931         Mexican                5     Excellent
# 34932  Middle Eastern                5     Excellent
#
#                                            description
# 0                        Heuristic pairing assessment.
# 1                        Heuristic pairing assessment.
# 2                    Acidic wine balances acidic food.
# 3                 Tannic red complements red meat fat.
# 4                        Heuristic pairing assessment.
# ...                                                ...
# 34928  Idealized perfect pairing example for contrast.
# 34929  Idealized perfect pairing example for contrast.
# 34930   Deliberately bad pairing example for contrast.
# 34931  Idealized perfect pairing example for contrast.
# 34932  Idealized perfect pairing example for contrast.
#
# [34933 rows x 8 columns]

# %%
from itertools import combinations
from scipy.stats import chi2_contingency

categorical_cols = ['wine_type', 'wine_category', 'food_item', 'food_category', 'cuisine']

for var1, var2 in combinations(categorical_cols, 2):
    contingency = pd.crosstab(df[var1], df[var2])
    chi2, p, dof, _ = chi2_contingency(contingency)
    result = "✅ Significant" if p < 0.05 else "❌ Not significant"
    print(f"{var1} vs {var2}: p-value={p:.4f} → {result}")
# Out:
# wine_type vs wine_category: p-value=0.0000 → ✅ Significant
# wine_type vs food_item: p-value=0.0000 → ✅ Significant
# wine_type vs food_category: p-value=0.0000 → ✅ Significant
# wine_type vs cuisine: p-value=1.0000 → ❌ Not significant
# wine_category vs food_item: p-value=0.0000 → ✅ Significant
# wine_category vs food_category: p-value=0.0000 → ✅ Significant
# wine_category vs cuisine: p-value=1.0000 → ❌ Not significant
# food_item vs food_category: p-value=0.0000 → ✅ Significant
# food_item vs cuisine: p-value=1.0000 → ❌ Not significant
# food_category vs cuisine: p-value=1.0000 → ❌ Not significant

# %%
# ---------------------------------------------------------------------------------
# 2 - Create unique IDs for wines and foods and Create Datafrme with IDs and Names
# ---------------------------------------------------------------------------------

df['wine_id'] = df['wine_type'].astype('category').cat.codes
df['food_id'] = df['food_item'].astype('category').cat.codes

df[['wine_type', 'wine_id', 'food_item', 'food_id']].head()

labels_df = df[['wine_type', 'wine_id', 'food_item', 'food_id']]

try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Yaml configuration file not found!")

labels_df.to_csv(config['output_data']['labels_file'], index=False)

# %%
labels_df
# Out:
#                 wine_type  wine_id          food_item  food_id
# 0            Syrah/Shiraz       23     smoked sausage       34
# 1                Grenache        9  charcuterie board       10
# 2                 Madeira       12         lemon tart       24
# 3      Cabernet Sauvignon        2         roast lamb       32
# 4                Viognier       26    duck à l’orange       17
# ...                   ...      ...                ...      ...
# 34928              Merlot       14     mac and cheese       25
# 34929           Sauternes       21     grilled ribeye       22
# 34930           Sauternes       21             fondue       19
# 34931           Zinfandel       28          beef stew        7
# 34932            Albariño        0         roast lamb       32
#
# [34933 rows x 4 columns]

# %%
# ------------------------------------------------------------------
# 3️ - One-Hot Encode categorical variables
# ------------------------------------------------------------------
# Columns to one-hot encode
categorical_cols = ['wine_type', 'wine_category', 'food_item', 'food_category', 'cuisine']

# Use pandas get_dummies
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print("After One-Hot Encoding:", df_encoded.shape)
df_encoded.head()
# Out:
# After One-Hot Encoding: (34933, 102)
#    pairing_quality quality_label                           description  \
# 0                2          Poor         Heuristic pairing assessment.
# 1                3       Neutral         Heuristic pairing assessment.
# 2                4          Good     Acidic wine balances acidic food.
# 3                5     Excellent  Tannic red complements red meat fat.
# 4                2          Poor         Heuristic pairing assessment.
#
#    wine_id  food_id  wine_type_Barbera  wine_type_Cabernet Sauvignon  \
# 0       23       34              False                         False
# 1        9       10              False                         False
# 2       12       24              False                         False
# 3        2       32              False                          True
# 4       26       17              False                         False
#
#    wine_type_Cava  wine_type_Champagne  wine_type_Chardonnay  ...  \
# 0           False                False                 False  ...
# 1           False                False                 False  ...
# 2           False                False                 False  ...
# 3           False                False                 False  ...
# 4           False                False                 False  ...
#
#    cuisine_Indian  cuisine_Italian  cuisine_Japanese  cuisine_Korean  \
# 0           False            False             False           False
# 1           False            False             False           False
# 2           False            False             False           False
# 3           False            False             False           False
# 4           False            False             False           False
#
#    cuisine_Mexican  cuisine_Middle Eastern  cuisine_Moroccan  cuisine_Spanish  \
# 0            False                   False             False             True
# 1            False                   False             False            False
# 2            False                   False             False            False
# 3             True                   False             False            False
# 4            False                   False             False            False
#
#    cuisine_Thai  cuisine_Vietnamese
# 0         False               False
# 1         False               False
# 2         False               False
# 3         False               False
# 4         False                True
#
# [5 rows x 102 columns]

# %%
# ------------------------------------------------------------------
# 4 - Define target variable (pairing score)
# ------------------------------------------------------------------

target_col = 'pairing_quality'
assert target_col in df_encoded.columns, f"Target column '{target_col}' not found."

df_encoded[target_col].value_counts().sort_index()
# Out:
# pairing_quality
# 1    7034
# 2    6179
# 3    8108
# 4    6449
# 5    7163
# Name: count, dtype: int64

# %%
# ------------------------------------------------------------------
# 5 - Split into Train / Test sets (80/20)
# ------------------------------------------------------------------

from sklearn.model_selection import train_test_split

# Define features and target
X = df_encoded.drop(columns=[target_col])
y = df_encoded[target_col]

# Use the original categorical column for stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=df['wine_type'])

print(f"Train samples: {X_train.shape[0]}  |  Test samples: {X_test.shape[0]}")
# Out:
# Train samples: 27946  |  Test samples: 6987

# %%
# ------------------------------------------------------------------
# 6 - Save clean datasets
# ------------------------------------------------------------------
import yaml

# Load YAML config
with open("../config.yaml", "r") as f:
    config = yaml.safe_load(f)

# Prepare datasets
train_df = X_train.copy()
train_df[target_col] = y_train
test_df = X_test.copy()
test_df[target_col] = y_test

# Save using config paths
train_df.to_csv(config['output_data']['train_file'], index=False)
test_df.to_csv(config['output_data']['test_file'], index=False)

print("✅ Data preparation complete. Files saved:")
print(f"  {config['output_data']['train_file']}")
print(f"  {config['output_data']['test_file']}")
# Out:
# ✅ Data preparation complete. Files saved:
#   ../data/clean/train_file.csv
#   ../data/clean/test_file.csv

# %%
train_df
# Out:
#       quality_label                                      description  wine_id  \
# 23065          Poor           Delicate wine overwhelmed by red meat.       21
# 285        Terrible                        Too lean for creamy dish.       15
# 19261     Excellent  Idealized perfect pairing example for contrast.        3
# 23716      Terrible   Deliberately bad pairing example for contrast.       20
# 20067      Terrible         Tannic reds clash with delicate seafood.       21
# ...             ...                                              ...      ...
# 10128       Neutral         Tannic reds clash with delicate seafood.       11
# 16667          Poor                    Heuristic pairing assessment.        6
# 20275       Neutral           Delicate wine overwhelmed by red meat.       16
# 8976           Poor                    Heuristic pairing assessment.       23
# 12746      Terrible   Deliberately bad pairing example for contrast.       25
#
#        food_id  wine_type_Barbera  wine_type_Cabernet Sauvignon  \
# 23065       32              False                         False
# 285         16              False                         False
# 19261        7              False                         False
# 23716       37              False                         False
# 20067       33              False                         False
# ...        ...                ...                           ...
# 10128       33              False                         False
# 16667       22              False                         False
# 20275       32              False                         False
# 8976        34              False                         False
# 12746        0              False                         False
#
#        wine_type_Cava  wine_type_Champagne  wine_type_Chardonnay  \
# 23065           False                False                 False
# 285             False                False                 False
# 19261            True                False                 False
# 23716           False                False                 False
# 20067           False                False                 False
# ...               ...                  ...                   ...
# 10128           False                False                 False
# 16667           False                False                 False
# 20275           False                False                 False
# 8976            False                False                 False
# 12746           False                False                 False
#
#        wine_type_Chenin Blanc  ...  cuisine_Italian  cuisine_Japanese  \
# 23065                   False  ...             True             False
# 285                     False  ...            False             False
# 19261                   False  ...            False             False
# 23716                   False  ...            False             False
# 20067                   False  ...            False             False
# ...                       ...  ...              ...               ...
# 10128                   False  ...            False             False
# 16667                    True  ...            False             False
# 20275                   False  ...            False             False
# 8976                    False  ...            False             False
# 12746                   False  ...            False             False
#
#        cuisine_Korean  cuisine_Mexican  cuisine_Middle Eastern  \
# 23065           False            False                   False
# 285             False            False                   False
# 19261           False            False                   False
# 23716            True            False                   False
# 20067           False            False                   False
# ...               ...              ...                     ...
# 10128           False            False                   False
# 16667           False            False                   False
# 20275           False            False                   False
# 8976            False            False                   False
# 12746            True            False                   False
#
#        cuisine_Moroccan  cuisine_Spanish  cuisine_Thai  cuisine_Vietnamese  \
# 23065             False            False         False               False
# 285               False            False         False               False
# 19261             False            False         False               False
# 23716             False            False         False               False
# 20067              True            False         False               False
# ...                 ...              ...           ...                 ...
# 10128             False            False         False                True
# 16667             False            False         False               False
# 20275              True            False         False               False
# 8976              False            False         False               False
# 12746             False            False         False               False
#
#        pairing_quality
# 23065                2
# 285                  1
# 19261                5
# 23716                1
# 20067                1
# ...                ...
# 10128                3
# 16667                2
# 20275                3
# 8976                 2
# 12746                1
#
# [27946 rows x 102 columns]

# %%
test_df
# Out:
#       quality_label                                      description  wine_id  \
# 10991          Poor         Tannic reds clash with delicate seafood.        7
# 13018          Poor                    Heuristic pairing assessment.        3
# 27430      Terrible   Deliberately bad pairing example for contrast.       21
# 28946     Excellent                Acidic wine balances acidic food.       28
# 16530          Poor           Delicate wine overwhelmed by red meat.        4
# ...             ...                                              ...      ...
# 3014        Neutral                     Crisp acidity suits seafood.        4
# 14147       Neutral                Acidic wine balances acidic food.       12
# 16724          Good                    Heuristic pairing assessment.       28
# 30578     Excellent  Idealized perfect pairing example for contrast.       26
# 3408        Neutral                       Lighter wines fit poultry.       16
#
#        food_id  wine_type_Barbera  wine_type_Cabernet Sauvignon  \
# 10991       29              False                         False
# 13018       19              False                         False
# 27430       28              False                         False
# 28946       15              False                         False
# 16530        5              False                         False
# ...        ...                ...                           ...
# 3014        18              False                         False
# 14147       24              False                         False
# 16724       11              False                         False
# 30578       20              False                         False
# 3408        13              False                         False
#
#        wine_type_Cava  wine_type_Champagne  wine_type_Chardonnay  \
# 10991           False                False                 False
# 13018            True                False                 False
# 27430           False                False                 False
# 28946           False                False                 False
# 16530           False                 True                 False
# ...               ...                  ...                   ...
# 3014            False                 True                 False
# 14147           False                False                 False
# 16724           False                False                 False
# 30578           False                False                 False
# 3408            False                False                 False
#
#        wine_type_Chenin Blanc  ...  cuisine_Italian  cuisine_Japanese  \
# 10991                   False  ...            False             False
# 13018                   False  ...            False             False
# 27430                   False  ...            False             False
# 28946                   False  ...             True             False
# 16530                   False  ...            False             False
# ...                       ...  ...              ...               ...
# 3014                    False  ...            False             False
# 14147                   False  ...             True             False
# 16724                   False  ...            False             False
# 30578                   False  ...            False             False
# 3408                    False  ...            False             False
#
#        cuisine_Korean  cuisine_Mexican  cuisine_Middle Eastern  \
# 10991           False             True                   False
# 13018           False            False                   False
# 27430           False            False                   False
# 28946           False            False                   False
# 16530           False            False                   False
# ...               ...              ...                     ...
# 3014            False            False                   False
# 14147           False            False                   False
# 16724           False            False                   False
# 30578           False            False                   False
# 3408            False            False                   False
#
#        cuisine_Moroccan  cuisine_Spanish  cuisine_Thai  cuisine_Vietnamese  \
# 10991             False            False         False               False
# 13018             False            False         False               False
# 27430             False             True         False               False
# 28946             False            False         False               False
# 16530             False            False         False               False
# ...                 ...              ...           ...                 ...
# 3014              False            False         False               False
# 14147             False            False         False               False
# 16724             False            False         False               False
# 30578             False            False         False               False
# 3408              False            False         False                True
#
#        pairing_quality
# 10991                2
# 13018                2
# 27430                1
# 28946                5
# 16530                2
# ...                ...
# 3014                 3
# 14147                3
# 16724                4
# 30578                5
# 3408                 3
#
# [6987 rows x 102 columns]
