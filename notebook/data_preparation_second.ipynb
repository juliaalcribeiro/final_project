# %%
import yaml
 
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Yaml configuration file not found!")

# %%
# ------------------------------------------------------------------
# 1 - Load dataset
# ------------------------------------------------------------------

import pandas as pd

df = pd.read_csv(config['input_data']['file'])
df
# Out:
#                 wine_type wine_category          food_item food_category  \
# 0            Syrah/Shiraz           Red     smoked sausage     Smoky BBQ
# 1                Grenache           Red  charcuterie board   Salty Snack
# 2                 Madeira     Fortified         lemon tart       Dessert
# 3      Cabernet Sauvignon           Red         roast lamb      Red Meat
# 4                Viognier         White    duck à l’orange       Poultry
# ...                   ...           ...                ...           ...
# 34928              Merlot           Red     mac and cheese        Cheese
# 34929           Sauternes       Dessert     grilled ribeye      Red Meat
# 34930           Sauternes       Dessert             fondue        Cheese
# 34931           Zinfandel           Red          beef stew      Red Meat
# 34932            Albariño         White         roast lamb      Red Meat
#
#               cuisine  pairing_quality quality_label  \
# 0             Spanish                2          Poor
# 1              French                3       Neutral
# 2              French                4          Good
# 3             Mexican                5     Excellent
# 4          Vietnamese                2          Poor
# ...               ...              ...           ...
# 34928           Greek                5     Excellent
# 34929         Spanish                5     Excellent
# 34930         Mexican                1      Terrible
# 34931         Mexican                5     Excellent
# 34932  Middle Eastern                5     Excellent
#
#                                            description
# 0                        Heuristic pairing assessment.
# 1                        Heuristic pairing assessment.
# 2                    Acidic wine balances acidic food.
# 3                 Tannic red complements red meat fat.
# 4                        Heuristic pairing assessment.
# ...                                                ...
# 34928  Idealized perfect pairing example for contrast.
# 34929  Idealized perfect pairing example for contrast.
# 34930   Deliberately bad pairing example for contrast.
# 34931  Idealized perfect pairing example for contrast.
# 34932  Idealized perfect pairing example for contrast.
#
# [34933 rows x 8 columns]

# %%
from itertools import combinations
from scipy.stats import chi2_contingency

categorical_cols = ['wine_type', 'wine_category', 'food_item', 'food_category', 'cuisine']

for var1, var2 in combinations(categorical_cols, 2):
    contingency = pd.crosstab(df[var1], df[var2])
    chi2, p, dof, _ = chi2_contingency(contingency)
    result = "✅ Significant" if p < 0.05 else "❌ Not significant"
    print(f"{var1} vs {var2}: p-value={p:.4f} → {result}")
# Out:
# wine_type vs wine_category: p-value=0.0000 → ✅ Significant
# wine_type vs food_item: p-value=0.0000 → ✅ Significant
# wine_type vs food_category: p-value=0.0000 → ✅ Significant
# wine_type vs cuisine: p-value=1.0000 → ❌ Not significant
# wine_category vs food_item: p-value=0.0000 → ✅ Significant
# wine_category vs food_category: p-value=0.0000 → ✅ Significant
# wine_category vs cuisine: p-value=1.0000 → ❌ Not significant
# food_item vs food_category: p-value=0.0000 → ✅ Significant
# food_item vs cuisine: p-value=1.0000 → ❌ Not significant
# food_category vs cuisine: p-value=1.0000 → ❌ Not significant

# %%
# ---------------------------------------------------------------------------------
# 2 - Create unique IDs for wines and foods and Create Datafrme with IDs and Names
# ---------------------------------------------------------------------------------

df['wine_type_id'] = df['wine_type'].astype('category').cat.codes
df['wine_category_id'] = df['wine_category'].astype('category').cat.codes
df['food_item_id'] = df['food_item'].astype('category').cat.codes
df['food_category_id'] = df['food_category'].astype('category').cat.codes
df['cuisine_id'] = df['cuisine'].astype('category').cat.codes

df[['wine_type', 'wine_type_id', 'wine_category', 'wine_category_id', 'food_item', 'food_item_id', 'food_category', 'food_category_id', 'cuisine', 'cuisine_id']].head()

labels_df = df[['wine_type', 'wine_type_id', 'wine_category', 'wine_category_id', 'food_item', 'food_item_id', 'food_category', 'food_category_id', 'cuisine', 'cuisine_id']]

try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Yaml configuration file not found!")

labels_df.to_csv(config['output_data']['labels_file'], index=False)

# %%
labels_df
# Out:
#                 wine_type  wine_type_id wine_category  wine_category_id  \
# 0            Syrah/Shiraz            23           Red                 2
# 1                Grenache             9           Red                 2
# 2                 Madeira            12     Fortified                 1
# 3      Cabernet Sauvignon             2           Red                 2
# 4                Viognier            26         White                 5
# ...                   ...           ...           ...               ...
# 34928              Merlot            14           Red                 2
# 34929           Sauternes            21       Dessert                 0
# 34930           Sauternes            21       Dessert                 0
# 34931           Zinfandel            28           Red                 2
# 34932            Albariño             0         White                 5
#
#                food_item  food_item_id food_category  food_category_id  \
# 0         smoked sausage            34     Smoky BBQ                 9
# 1      charcuterie board            10   Salty Snack                 7
# 2             lemon tart            24       Dessert                 3
# 3             roast lamb            32      Red Meat                 6
# 4        duck à l’orange            17       Poultry                 5
# ...                  ...           ...           ...               ...
# 34928     mac and cheese            25        Cheese                 1
# 34929     grilled ribeye            22      Red Meat                 6
# 34930             fondue            19        Cheese                 1
# 34931          beef stew             7      Red Meat                 6
# 34932         roast lamb            32      Red Meat                 6
#
#               cuisine  cuisine_id
# 0             Spanish          14
# 1              French           4
# 2              French           4
# 3             Mexican          11
# 4          Vietnamese          16
# ...               ...         ...
# 34928           Greek           6
# 34929         Spanish          14
# 34930         Mexican          11
# 34931         Mexican          11
# 34932  Middle Eastern          12
#
# [34933 rows x 10 columns]

# %%
# ------------------------------------------------------------------
# 3️ - One-Hot Encode categorical variables
# ------------------------------------------------------------------
# Columns to one-hot encode
categorical_cols = ['wine_type', 'wine_category', 'food_item', 'food_category', 'cuisine']

# Use pandas get_dummies
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print("After One-Hot Encoding:", df_encoded.shape)
df_encoded.head()
# Out:
# After One-Hot Encoding: (34933, 105)
#    pairing_quality quality_label                           description  \
# 0                2          Poor         Heuristic pairing assessment.
# 1                3       Neutral         Heuristic pairing assessment.
# 2                4          Good     Acidic wine balances acidic food.
# 3                5     Excellent  Tannic red complements red meat fat.
# 4                2          Poor         Heuristic pairing assessment.
#
#    wine_type_id  wine_category_id  food_item_id  food_category_id  cuisine_id  \
# 0            23                 2            34                 9          14
# 1             9                 2            10                 7           4
# 2            12                 1            24                 3           4
# 3             2                 2            32                 6          11
# 4            26                 5            17                 5          16
#
#    wine_type_Barbera  wine_type_Cabernet Sauvignon  ...  cuisine_Indian  \
# 0              False                         False  ...           False
# 1              False                         False  ...           False
# 2              False                         False  ...           False
# 3              False                          True  ...           False
# 4              False                         False  ...           False
#
#    cuisine_Italian  cuisine_Japanese  cuisine_Korean  cuisine_Mexican  \
# 0            False             False           False            False
# 1            False             False           False            False
# 2            False             False           False            False
# 3            False             False           False             True
# 4            False             False           False            False
#
#    cuisine_Middle Eastern  cuisine_Moroccan  cuisine_Spanish  cuisine_Thai  \
# 0                   False             False             True         False
# 1                   False             False            False         False
# 2                   False             False            False         False
# 3                   False             False            False         False
# 4                   False             False            False         False
#
#    cuisine_Vietnamese
# 0               False
# 1               False
# 2               False
# 3               False
# 4                True
#
# [5 rows x 105 columns]

# %%
# ------------------------------------------------------------------
# 4 - Define target variable (pairing score)
# ------------------------------------------------------------------

target_col = 'pairing_quality'
assert target_col in df_encoded.columns, f"Target column '{target_col}' not found."

df_encoded[target_col].value_counts().sort_index()
# Out:
# pairing_quality
# 1    7034
# 2    6179
# 3    8108
# 4    6449
# 5    7163
# Name: count, dtype: int64

# %%
# ------------------------------------------------------------------
# 5 - Split into Train / Test sets (80/20)
# ------------------------------------------------------------------

from sklearn.model_selection import train_test_split

# Define features and target
X = df_encoded.drop(columns=[target_col])
y = df_encoded[target_col]

# Use the original categorical column for stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=df['wine_type'])

print(f"Train samples: {X_train.shape[0]}  |  Test samples: {X_test.shape[0]}")
# Out:
# Train samples: 27946  |  Test samples: 6987

# %%
# ------------------------------------------------------------------
# 6 - Save clean datasets
# ------------------------------------------------------------------
import yaml

# Load YAML config
with open("../config.yaml", "r") as f:
    config = yaml.safe_load(f)

# Prepare datasets
train_df = X_train.copy()
train_df[target_col] = y_train
test_df = X_test.copy()
test_df[target_col] = y_test

# Save using config paths
train_df.to_csv(config['output_data']['train_file'], index=False)
test_df.to_csv(config['output_data']['test_file'], index=False)

print("✅ Data preparation complete. Files saved:")
print(f"  {config['output_data']['train_file']}")
print(f"  {config['output_data']['test_file']}")
# Out:
# ✅ Data preparation complete. Files saved:
#   ../data/clean/train_file.csv
#   ../data/clean/test_file.csv

# %%
train_df
# Out:
#       quality_label                                      description  \
# 23065          Poor           Delicate wine overwhelmed by red meat.
# 285        Terrible                        Too lean for creamy dish.
# 19261     Excellent  Idealized perfect pairing example for contrast.
# 23716      Terrible   Deliberately bad pairing example for contrast.
# 20067      Terrible         Tannic reds clash with delicate seafood.
# ...             ...                                              ...
# 10128       Neutral         Tannic reds clash with delicate seafood.
# 16667          Poor                    Heuristic pairing assessment.
# 20275       Neutral           Delicate wine overwhelmed by red meat.
# 8976           Poor                    Heuristic pairing assessment.
# 12746      Terrible   Deliberately bad pairing example for contrast.
#
#        wine_type_id  wine_category_id  food_item_id  food_category_id  \
# 23065            21                 0            32                 6
# 285              15                 2            16                 2
# 19261             3                 4             7                 6
# 23716            20                 2            37                11
# 20067            21                 0            33                 8
# ...             ...               ...           ...               ...
# 10128            11                 0            33                 8
# 16667             6                 5            22                 6
# 20275            16                 2            32                 6
# 8976             23                 2            34                 9
# 12746            25                 5             0                10
#
#        cuisine_id  wine_type_Barbera  wine_type_Cabernet Sauvignon  \
# 23065           8              False                         False
# 285             7              False                         False
# 19261           3              False                         False
# 23716          10              False                         False
# 20067          13              False                         False
# ...           ...                ...                           ...
# 10128          16              False                         False
# 16667           5              False                         False
# 20275          13              False                         False
# 8976            7              False                         False
# 12746          10              False                         False
#
#        wine_type_Cava  ...  cuisine_Italian  cuisine_Japanese  cuisine_Korean  \
# 23065           False  ...             True             False           False
# 285             False  ...            False             False           False
# 19261            True  ...            False             False           False
# 23716           False  ...            False             False            True
# 20067           False  ...            False             False           False
# ...               ...  ...              ...               ...             ...
# 10128           False  ...            False             False           False
# 16667           False  ...            False             False           False
# 20275           False  ...            False             False           False
# 8976            False  ...            False             False           False
# 12746           False  ...            False             False            True
#
#        cuisine_Mexican  cuisine_Middle Eastern  cuisine_Moroccan  \
# 23065            False                   False             False
# 285              False                   False             False
# 19261            False                   False             False
# 23716            False                   False             False
# 20067            False                   False              True
# ...                ...                     ...               ...
# 10128            False                   False             False
# 16667            False                   False             False
# 20275            False                   False              True
# 8976             False                   False             False
# 12746            False                   False             False
#
#        cuisine_Spanish  cuisine_Thai  cuisine_Vietnamese  pairing_quality
# 23065            False         False               False                2
# 285              False         False               False                1
# 19261            False         False               False                5
# 23716            False         False               False                1
# 20067            False         False               False                1
# ...                ...           ...                 ...              ...
# 10128            False         False                True                3
# 16667            False         False               False                2
# 20275            False         False               False                3
# 8976             False         False               False                2
# 12746            False         False               False                1
#
# [27946 rows x 105 columns]

# %%
test_df
# Out:
#       quality_label                                      description  \
# 10991          Poor         Tannic reds clash with delicate seafood.
# 13018          Poor                    Heuristic pairing assessment.
# 27430      Terrible   Deliberately bad pairing example for contrast.
# 28946     Excellent                Acidic wine balances acidic food.
# 16530          Poor           Delicate wine overwhelmed by red meat.
# ...             ...                                              ...
# 3014        Neutral                     Crisp acidity suits seafood.
# 14147       Neutral                Acidic wine balances acidic food.
# 16724          Good                    Heuristic pairing assessment.
# 30578     Excellent  Idealized perfect pairing example for contrast.
# 3408        Neutral                       Lighter wines fit poultry.
#
#        wine_type_id  wine_category_id  food_item_id  food_category_id  \
# 10991             7                 2            29                 8
# 13018             3                 4            19                 1
# 27430            21                 0            28                 7
# 28946            28                 2            15                 0
# 16530             4                 4             5                 6
# ...             ...               ...           ...               ...
# 3014              4                 4            18                 8
# 14147            12                 1            24                 3
# 16724            28                 2            11                 1
# 30578            26                 5            20                 0
# 3408             16                 2            13                 5
#
#        cuisine_id  wine_type_Barbera  wine_type_Cabernet Sauvignon  \
# 10991          11              False                         False
# 13018           5              False                         False
# 27430          14              False                         False
# 28946           8              False                         False
# 16530           3              False                         False
# ...           ...                ...                           ...
# 3014            4              False                         False
# 14147           8              False                         False
# 16724           5              False                         False
# 30578           1              False                         False
# 3408           16              False                         False
#
#        wine_type_Cava  ...  cuisine_Italian  cuisine_Japanese  cuisine_Korean  \
# 10991           False  ...            False             False           False
# 13018            True  ...            False             False           False
# 27430           False  ...            False             False           False
# 28946           False  ...             True             False           False
# 16530           False  ...            False             False           False
# ...               ...  ...              ...               ...             ...
# 3014            False  ...            False             False           False
# 14147           False  ...             True             False           False
# 16724           False  ...            False             False           False
# 30578           False  ...            False             False           False
# 3408            False  ...            False             False           False
#
#        cuisine_Mexican  cuisine_Middle Eastern  cuisine_Moroccan  \
# 10991             True                   False             False
# 13018            False                   False             False
# 27430            False                   False             False
# 28946            False                   False             False
# 16530            False                   False             False
# ...                ...                     ...               ...
# 3014             False                   False             False
# 14147            False                   False             False
# 16724            False                   False             False
# 30578            False                   False             False
# 3408             False                   False             False
#
#        cuisine_Spanish  cuisine_Thai  cuisine_Vietnamese  pairing_quality
# 10991            False         False               False                2
# 13018            False         False               False                2
# 27430             True         False               False                1
# 28946            False         False               False                5
# 16530            False         False               False                2
# ...                ...           ...                 ...              ...
# 3014             False         False               False                3
# 14147            False         False               False                3
# 16724            False         False               False                4
# 30578            False         False               False                5
# 3408             False         False                True                3
#
# [6987 rows x 105 columns]
